# %%
#####========================================= Import Libraries ============================================================

import pandas as pd
import numpy as np
import scipy
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.util import bigrams 
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import warnings
warnings.filterwarnings("ignore")

# %%
####==================================Import and read the dataset===========================================================

# Original dataset
df_orig = pd.read_csv("DataSet.csv")
df_orig = pd.DataFrame(df_orig)

# replicate for work
df = df_orig

#### =============== Unprocessed data ===========================
print(df.shape)
df.head()
# Out:
# (17880, 18)
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   salary_range                                    company_profile  \
# 0          NaN  <h3>We're Food52, and we've created a groundbr...
# 1          NaN  <h3>90 Seconds, the worlds Cloud Video Product...
# 2          NaN  <h3></h3>\r\n<p>Valor Services provides Workfo...
# 3          NaN  <p>Our passion for improving quality of life t...
# 4          NaN  <p>SpotSource Solutions LLC is a Global Human ...
#
#                                          description  \
# 0  <p>Food52, a fast-growing, James Beard Award-w...
# 1  <p>Organised - Focused - Vibrant - Awesome!<br...
# 2  <p>Our client, located in Houston, is actively...
# 3  <p><b>THE COMPANY: ESRI – Environmental System...
# 4  <p><b>JOB TITLE:</b> Itemization Review Manage...
#
#                                         requirements  \
# 0  <ul>\r\n<li>Experience with content management...
# 1  <p><b>What we expect from you:</b></p>\r\n<p>Y...
# 2  <ul>\r\n<li>Implement pre-commissioning and co...
# 3  <ul>\r\n<li>\r\n<b>EDUCATION: </b>Bachelor’s o...
# 4  <p><b>QUALIFICATIONS:</b></p>\r\n<ul>\r\n<li>R...
#
#                                             benefits telecommuting  \
# 0                                                NaN             f
# 1  <h3><b>What you will get from us</b></h3>\r\n<...             f
# 2                                                NaN             f
# 3  <p>Our culture is anything but corporate—we ha...             f
# 4                       <p>Full Benefits Offered</p>             f
#
#   has_company_logo has_questions employment_type required_experience  \
# 0                t             f           Other          Internship
# 1                t             f       Full-time      Not Applicable
# 2                t             f             NaN                 NaN
# 3                t             f       Full-time    Mid-Senior level
# 4                t             t       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#   fraudulent in_balanced_dataset
# 0          f                   f
# 1          f                   f
# 2          f                   f
# 3          f                   f
# 4          f                   f

# %%
####====================================== Data Preprocessing: ============================================================

##### Steps Involved:

#1) Remove HTML Tags 

#2) Tokenization

#3) Remove Punctuations

#4) Lemmatization

#5) Remove Stopword

# %% [markdown]
# ### Remove HTML Tags

# %%
import re

def remove_html_tags(text):
    return re.sub('<[^<]+?>', '', str(text))


df.company_profile=df.company_profile.apply(remove_html_tags).str.replace('\r\n', '').str.replace('&amp', 'and').str.lower()
df.description=df.description.apply(remove_html_tags).str.replace('\r\n', '').str.replace('&amp', 'and').str.lower()
df.requirements=df.requirements.apply(remove_html_tags).str.replace('\r\n', '').str.replace('&amp', 'and').str.lower()
df.benefits=df.benefits.apply(remove_html_tags).str.replace('\r\n', '').str.replace('&amp', 'and').str.lower()
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   salary_range                                    company_profile  \
# 0          NaN  we're food52, and we've created a groundbreaki...
# 1          NaN  90 seconds, the worlds cloud video production ...
# 2          NaN  valor services provides workforce solutions th...
# 3          NaN  our passion for improving quality of life thro...
# 4          NaN  spotsource solutions llc is a global human cap...
#
#                                          description  \
# 0  food52, a fast-growing, james beard award-winn...
# 1  organised - focused - vibrant - awesome!do you...
# 2  our client, located in houston, is actively se...
# 3  the company: esri – environmental systems rese...
# 4  job title: itemization review managerlocation:...
#
#                                         requirements  \
# 0  experience with content management systems a m...
# 1  what we expect from you:your key responsibilit...
# 2  implement pre-commissioning and commissioning ...
# 3  education: bachelor’s or master’s in gis, busi...
# 4  qualifications:rn license in the state of texa...
#
#                                             benefits telecommuting  \
# 0                                                nan             f
# 1  what you will get from usthrough being part of...             f
# 2                                                nan             f
# 3  our culture is anything but corporate—we have ...             f
# 4                              full benefits offered             f
#
#   has_company_logo has_questions employment_type required_experience  \
# 0                t             f           Other          Internship
# 1                t             f       Full-time      Not Applicable
# 2                t             f             NaN                 NaN
# 3                t             f       Full-time    Mid-Senior level
# 4                t             t       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#   fraudulent in_balanced_dataset
# 0          f                   f
# 1          f                   f
# 2          f                   f
# 3          f                   f
# 4          f                   f

# %% [markdown]
# ### Tokenization and Remove Punctuations

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
df['company_profile'] = df['company_profile'].apply(lambda x: tokenizer.tokenize(x))
df['description'] = df['description'].apply(lambda x: tokenizer.tokenize(x))
df['requirements'] = df['requirements'].apply(lambda x: tokenizer.tokenize(x))
df['benefits'] = df['benefits'].apply(lambda x: tokenizer.tokenize(x))

df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   salary_range                                    company_profile  \
# 0          NaN  [we, re, food52, and, we, ve, created, a, grou...
# 1          NaN  [90, seconds, the, worlds, cloud, video, produ...
# 2          NaN  [valor, services, provides, workforce, solutio...
# 3          NaN  [our, passion, for, improving, quality, of, li...
# 4          NaN  [spotsource, solutions, llc, is, a, global, hu...
#
#                                          description  \
# 0  [food52, a, fast, growing, james, beard, award...
# 1  [organised, focused, vibrant, awesome, do, you...
# 2  [our, client, located, in, houston, is, active...
# 3  [the, company, esri, environmental, systems, r...
# 4  [job, title, itemization, review, managerlocat...
#
#                                         requirements  \
# 0  [experience, with, content, management, system...
# 1  [what, we, expect, from, you, your, key, respo...
# 2  [implement, pre, commissioning, and, commissio...
# 3  [education, bachelor, s, or, master, s, in, gi...
# 4  [qualifications, rn, license, in, the, state, ...
#
#                                             benefits telecommuting  \
# 0                                              [nan]             f
# 1  [what, you, will, get, from, usthrough, being,...             f
# 2                                              [nan]             f
# 3  [our, culture, is, anything, but, corporate, w...             f
# 4                          [full, benefits, offered]             f
#
#   has_company_logo has_questions employment_type required_experience  \
# 0                t             f           Other          Internship
# 1                t             f       Full-time      Not Applicable
# 2                t             f             NaN                 NaN
# 3                t             f       Full-time    Mid-Senior level
# 4                t             t       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#   fraudulent in_balanced_dataset
# 0          f                   f
# 1          f                   f
# 2          f                   f
# 3          f                   f
# 4          f                   f

# %% [markdown]
# ### Lemmatization of Tokens and Stopwords Removal

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import stopwords
stop = stopwords.words('english')

from nltk.stem import WordNetLemmatizer 
wordnet_lemmatizer = WordNetLemmatizer() 

def lemma(data):
    
    lemmatized_data = [wordnet_lemmatizer.lemmatize(word) for word in data]
    clean_data = [w for w in lemmatized_data if w not in stop]
    
    return clean_data

df['company_profile'] = df['company_profile'].apply(lambda x: lemma(x))
df['description'] = df['description'].apply(lambda x: lemma(x))
df['requirements'] = df['requirements'].apply(lambda x: lemma(x))
df['benefits'] = df['benefits'].apply(lambda x: lemma(x))


df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vashiv\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   salary_range                                    company_profile  \
# 0          NaN  [food52, created, groundbreaking, award, winni...
# 1          NaN  [90, second, world, cloud, video, production, ...
# 2          NaN  [valor, service, provides, workforce, solution...
# 3          NaN  [passion, improving, quality, life, geography,...
# 4          NaN  [spotsource, solution, llc, global, human, cap...
#
#                                          description  \
# 0  [food52, fast, growing, james, beard, award, w...
# 1  [organised, focused, vibrant, awesome, passion...
# 2  [client, located, houston, actively, seeking, ...
# 3  [company, esri, environmental, system, researc...
# 4  [job, title, itemization, review, managerlocat...
#
#                                         requirements  \
# 0  [experience, content, management, system, majo...
# 1  [expect, key, responsibility, communicate, cli...
# 2  [implement, pre, commissioning, commissioning,...
# 3  [education, bachelor, master, gi, business, ad...
# 4  [qualification, rn, license, state, texasdiplo...
#
#                                             benefits telecommuting  \
# 0                                              [nan]             f
# 1  [get, usthrough, part, 90, second, team, gain,...             f
# 2                                              [nan]             f
# 3  [culture, anything, corporate, collaborative, ...             f
# 4                           [full, benefit, offered]             f
#
#   has_company_logo has_questions employment_type required_experience  \
# 0                t             f           Other          Internship
# 1                t             f       Full-time      Not Applicable
# 2                t             f             NaN                 NaN
# 3                t             f       Full-time    Mid-Senior level
# 4                t             t       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#   fraudulent in_balanced_dataset
# 0          f                   f
# 1          f                   f
# 2          f                   f
# 3          f                   f
# 4          f                   f

# %%
#cleaned dataset for further analysis 
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever        NaN
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth        NaN
#
#   salary_range                                    company_profile  \
# 0          NaN  [food52, created, groundbreaking, award, winni...
# 1          NaN  [90, second, world, cloud, video, production, ...
# 2          NaN  [valor, service, provides, workforce, solution...
# 3          NaN  [passion, improving, quality, life, geography,...
# 4          NaN  [spotsource, solution, llc, global, human, cap...
#
#                                          description  \
# 0  [food52, fast, growing, james, beard, award, w...
# 1  [organised, focused, vibrant, awesome, passion...
# 2  [client, located, houston, actively, seeking, ...
# 3  [company, esri, environmental, system, researc...
# 4  [job, title, itemization, review, managerlocat...
#
#                                         requirements  \
# 0  [experience, content, management, system, majo...
# 1  [expect, key, responsibility, communicate, cli...
# 2  [implement, pre, commissioning, commissioning,...
# 3  [education, bachelor, master, gi, business, ad...
# 4  [qualification, rn, license, state, texasdiplo...
#
#                                             benefits telecommuting  \
# 0                                              [nan]             f
# 1  [get, usthrough, part, 90, second, team, gain,...             f
# 2                                              [nan]             f
# 3  [culture, anything, corporate, collaborative, ...             f
# 4                           [full, benefit, offered]             f
#
#   has_company_logo has_questions employment_type required_experience  \
# 0                t             f           Other          Internship
# 1                t             f       Full-time      Not Applicable
# 2                t             f             NaN                 NaN
# 3                t             f       Full-time    Mid-Senior level
# 4                t             t       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#   fraudulent in_balanced_dataset
# 0          f                   f
# 1          f                   f
# 2          f                   f
# 3          f                   f
# 4          f                   f

# %% [markdown]
# # Analyzing frequency of Token for Fraud postings

# %%
# creating a subset of dataframe with features which has relevancy for our analysis 
df_new = df[["industry", "description", "fraudulent","company_profile","benefits", "requirements"]]
df_new.isnull().sum()
df_new
# Out:
#                                   industry  \
# 0                                      NaN
# 1                Marketing and Advertising
# 2                                      NaN
# 3                        Computer Software
# 4                   Hospital & Health Care
# 5                                      NaN
# 6                             Online Media
# 7                                      NaN
# 8      Information Technology and Services
# 9                       Financial Services
# 10     Information Technology and Services
# 11                                     NaN
# 12                   Management Consulting
# 13                         Events Services
# 14                                Internet
# 15                     Facilities Services
# 16                                Internet
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
# 20                                     NaN
# 21                    Consumer Electronics
# 22                      Telecommunications
# 23                                Internet
# 24                                     NaN
# 25                                     NaN
# 26                            Online Media
# 27                  Hospital & Health Care
# 28                   Management Consulting
# 29                       Consumer Services
# ...                                    ...
# 17850           Logistics and Supply Chain
# 17851                      Food Production
# 17852  Information Technology and Services
# 17853                                  NaN
# 17854                                  NaN
# 17855                                  NaN
# 17856                    Computer Software
# 17857                          Hospitality
# 17858                      Pharmaceuticals
# 17859                                  NaN
# 17860  Information Technology and Services
# 17861                    Computer Hardware
# 17862                     Medical Practice
# 17863                    Computer Software
# 17864                                  NaN
# 17865                          Real Estate
# 17866             Motion Pictures and Film
# 17867                      Human Resources
# 17868                                  NaN
# 17869                      Pharmaceuticals
# 17870                               Retail
# 17871                         Oil & Energy
# 17872                             Internet
# 17873                            Utilities
# 17874                    Computer Software
# 17875                    Computer Software
# 17876                             Internet
# 17877                                  NaN
# 17878                       Graphic Design
# 17879                    Computer Software
#
#                                              description fraudulent  \
# 0      [food52, fast, growing, james, beard, award, w...          f
# 1      [organised, focused, vibrant, awesome, passion...          f
# 2      [client, located, houston, actively, seeking, ...          f
# 3      [company, esri, environmental, system, researc...          f
# 4      [job, title, itemization, review, managerlocat...          f
# 5      [job, overviewapex, environmental, consulting,...          f
# 6      [responsibility, manage, english, speaking, ed...          f
# 7      [airenvy, hey, seasoned, entrepreneur, heart, ...          f
# 8      [implementation, configuration, testing, train...          f
# 9      [customer, service, associate, based, phoenix,...          f
# 10     [position, url_86fd830a95a64e2b30ceed829e63fd3...          f
# 11     [transferwise, clever, new, way, move, money, ...          f
# 12     [application, developer, digital, develop, par...          f
# 13     [event, industry, installers, needed, orlando,...          f
# 14     [interested, satisfying, financially, rewardin...          f
# 15     [vault, dragon, vault, dragon, dropbox, physic...          f
# 16     [looking, hand, qa, leader, talented, rand, te...          f
# 17     [government, funding, available, 16, 18, year,...          f
# 18     [kettle, hiring, visual, designer, job, locati...          f
# 19     [experienced, process, control, engineer, requ...          f
# 20     [intellibright, growing, fast, looking, market...          f
# 21     [want, part, globally, focused, tech, team, de...          f
# 22     [position, report, head, engagement, managemen...          f
# 23     [url_eda2500ddcedb60957fcd7f5b164e092966f8c4e8...          f
# 24     [canary, wharf, based, e, commerce, company, r...          f
# 25     [hello, wish, good, regarding, job, opportunit...          f
# 26     [currently, expanding, marketing, department, ...          f
# 27     [haad, dha, licensed, doctor, opening, uaewe, ...          f
# 28     [1500, job, opening, website, relevant, job, f...          f
# 29     [customer, service, associate, based, toronto,...          f
# ...                                                  ...        ...
# 17850  [looking, experienced, assessor, north, west, ...          f
# 17851  [red, star, yeast, co, llc, cedar, rapid, hiri...          f
# 17852  [gwt, expertwe, experiencing, rapid, worldwide...          f
# 17853  [command, care, enough, consistently, place, r...          f
# 17854  [1500, job, opening, website, relevant, job, f...          f
# 17855  [looking, integral, player, handful, apps, hit...          f
# 17856  [intercom, url_cb674f93cbcd215a3a0a57a8615a565...          f
# 17857  [want, join, fast, growing, start, equity, hol...          f
# 17858  [pharmaceutical, client, ha, engaged, u, provi...          f
# 17859  [greeting, vam, system, vam, system, business,...          f
# 17860  [position, sr, sql, server, dbalocation, bay, ...          f
# 17861  [aretribe, wearable, venture, backed, startup,...          f
# 17862  [crossroad, treatment, center, south, carolina...          f
# 17863  [wanted, implementation, support, specialist, ...          f
# 17864  [merl, looking, well, qualified, individual, i...          f
# 17865  [avenuestory, looking, curious, ambitious, ada...          f
# 17866  [key, duty, rough, cut, show, adobe, premier, ...          f
# 17867  [seeking, administrator, work, busy, sale, env...          f
# 17868  [1500, job, opening, website, relevant, job, f...          f
# 17869  [job, title, sr, technical, leadsalary, opendu...          f
# 17870  [activity, searching, senior, financial, analy...          f
# 17871  [requires, skilled, work, operating, commercia...          f
# 17872  [flite, saas, display, ad, platform, fuel, wor...          f
# 17873  [responsibility, facilitate, recruiting, hirin...          f
# 17874  [sr, javascript, developer, experience, 4, 10,...          f
# 17875  [case, first, time, visited, website, vend, aw...          f
# 17876  [payroll, accountant, focus, primarily, payrol...          f
# 17877  [experienced, project, cost, control, staff, e...          f
# 17878  [nemsia, studio, looking, experienced, visual,...          f
# 17879  [vend, award, winning, web, based, point, sale...          f
#
#                                          company_profile  \
# 0      [food52, created, groundbreaking, award, winni...
# 1      [90, second, world, cloud, video, production, ...
# 2      [valor, service, provides, workforce, solution...
# 3      [passion, improving, quality, life, geography,...
# 4      [spotsource, solution, llc, global, human, cap...
# 5                                                  [nan]
# 6      [founded, 2009, fonpit, ag, rose, internationa...
# 7      [airenvy, mission, provide, lucrative, yet, ha...
# 8      [solutions3, woman, owned, small, business, wh...
# 9      [novitex, enterprise, solution, formerly, pitn...
# 10                                                 [nan]
# 11     [want, build, 21st, century, financial, servic...
# 12     [novitex, enterprise, solution, formerly, pitn...
# 13     [growing, event, production, company, providin...
# 14     [adthena, uk, leading, competitive, intelligen...
# 15     [jungle, venture, leading, singapore, based, e...
# 16     [honeybook, imagining, event, industry, buildi...
# 17     [established, principle, full, time, education...
# 18     [kettle, independent, digital, agency, based, ...
# 19     [provide, full, time, permanent, position, man...
# 20     [intellibright, wa, created, leverage, enterpr...
# 21     [frustrated, status, quo, like, imagine, whats...
# 22     [upstream, mission, revolutionise, way, compan...
# 23     [wdm, group, innovative, forward, thinking, di...
# 24                                                 [nan]
# 25     [i28, technology, ha, demonstrated, expertise,...
# 26     [working, cubical, seems, like, idea, hell, jo...
# 27     [medical, recruitment, team, roland, associate...
# 28     [provide, full, time, permanent, position, man...
# 29     [novitex, enterprise, solution, formerly, pitn...
# ...                                                  ...
# 17850  [established, principle, full, time, education...
# 17851  [red, star, yeast, company, llc, rsyc, leader,...
# 17852                                              [nan]
# 17853  [command, care, enough, consistently, place, r...
# 17854  [provide, full, time, permanent, position, man...
# 17855  [shyp, easiest, way, send, anything, anywhere,...
# 17856  [intercom, url_cb674f93cbcd215a3a0a57a8615a565...
# 17857                                              [nan]
# 17858  [keen360, help, organization, design, strategy...
# 17859                                              [nan]
# 17860                                              [nan]
# 17861  [tribe, wearable, venture, backed, startup, de...
# 17862  [crossroad, treatment, center, nationally, acc...
# 17863  [design, build, sell, service, innovative, ope...
# 17864  [merl, internship, program, give, student, exc...
# 17865  [hiring, avenuestory, concept, driven, people,...
# 17866  [story, relfrom, 5, 000, foot, look, like, med...
# 17867                                              [nan]
# 17868  [provide, full, time, permanent, position, man...
# 17869                                              [nan]
# 17870  [prosulting, people, prosulting, difference, e...
# 17871  [valor, service, provides, workforce, solution...
# 17872  [flite, delivers, ad, innovation, scale, world...
# 17873                                              [nan]
# 17874                                              [nan]
# 17875  [vend, looking, awesome, new, talent, come, jo...
# 17876  [weblinc, e, commerce, platform, service, prov...
# 17877  [provide, full, time, permanent, position, man...
# 17878                                              [nan]
# 17879  [vend, looking, awesome, new, talent, come, jo...
#
#                                                 benefits  \
# 0                                                  [nan]
# 1      [get, usthrough, part, 90, second, team, gain,...
# 2                                                  [nan]
# 3      [culture, anything, corporate, collaborative, ...
# 4                               [full, benefit, offered]
# 5                                                  [nan]
# 6      [benefit, part, fast, growing, company, boomin...
# 7      [competitive, pay, able, eat, steak, everyday,...
# 8                                                  [nan]
# 9                                                  [nan]
# 10     [benefit, fullbonus, eligible, yesinterview, t...
# 11     [join, one, europe, hotly, tipped, startup, pl...
# 12                                                 [nan]
# 13                                                 [nan]
# 14     [return, pay, well, give, ownership, company, ...
# 15     [basic, sgd, 120, 000equity, negotiable, rock,...
# 16                                                 [nan]
# 17                                    [career, prospect]
# 18                                                 [nan]
# 19                                                 [nan]
# 20                                                 [nan]
# 21     [part, awesome, team, innovator, creator, er, ...
# 22     [salary, benefitsthe, opportunity, learn, grow...
# 23     [businessfriend, offer, competitive, six, figu...
# 24                                                 [nan]
# 25                                                 [nan]
# 26     [looking, singaporean, resident, international...
# 27     [client, one, reputed, leading, health, care, ...
# 28                                                 [nan]
# 29                                                 [nan]
# ...                                                  ...
# 17850                                              [nan]
# 17851  [shift, schedule, day, shift, monday, friday, ...
# 17852                                              [nan]
# 17853  [benefit, 15, hr, non, negotiable, medical, de...
# 17854                                              [nan]
# 17855                                              [nan]
# 17856  [work, great, hardware, macbook, air, pro, cin...
# 17857                                              [nan]
# 17858                                              [nan]
# 17859                                              [nan]
# 17860                                              [nan]
# 17861  [fun, stimulating, working, environmentwork, a...
# 17862  [crossroad, offer, comprehensive, benefit, pac...
# 17863                                              [nan]
# 17864                                              [nan]
# 17865  [working, within, small, young, dynamic, team,...
# 17866  [salary, benefit, package, negotiable, based, ...
# 17867  [salary, 18, 000commission, available, qualify...
# 17868                                              [nan]
# 17869                                              [nan]
# 17870                                                 []
# 17871                                              [nan]
# 17872  [competitive, baseattractive, stock, option, p...
# 17873                                              [nan]
# 17874                                              [nan]
# 17875  [expect, u, open, culture, openly, share, resu...
# 17876  [health, wellnessmedical, planprescription, dr...
# 17877                                              [nan]
# 17878  [competitive, salary, compensation, based, exp...
# 17879                                              [nan]
#
#                                             requirements
# 0      [experience, content, management, system, majo...
# 1      [expect, key, responsibility, communicate, cli...
# 2      [implement, pre, commissioning, commissioning,...
# 3      [education, bachelor, master, gi, business, ad...
# 4      [qualification, rn, license, state, texasdiplo...
# 5                                                  [nan]
# 6      [know, university, college, degree, journalism...
# 7      [experience, crm, software, live, chat, phone,...
# 8      [must, u, citizen, active, sci, clearance, req...
# 9      [minimum, requirement, minimum, 6, month, cust...
# 10     [position, url_86fd830a95a64e2b30ceed829e63fd3...
# 11     [looking, someone, proven, track, record, sour...
# 12     [requirement, 4, 5, year, experience, developi...
# 13     [valid, driver, license, somewhat, clean, driv...
# 14     [need, smart, passionate, 2, year, experience,...
# 15     [key, superpowers3, 5, year, high, pressure, s...
# 16     [previous, experience, client, server, testing...
# 17     [16, 18, year, old, due, government, funding, ...
# 18                                                 [nan]
# 19     [must, 5, year, experience, dc, programming, t...
# 20     [job, requirementsassist, creating, client, on...
# 21     [likely, solid, mastery, modern, web, applicat...
# 22     [requirementsthe, ideal, candidate, bright, am...
# 23     [job, requirement, reputation, go, getter, rai...
# 24                                                 [nan]
# 25     [java, net, sql, oracle, sap, informatica, big...
# 26     [position, junior, mid, level, ideally, curios...
# 27     [requirementsendocrinologistgastroenterologist...
# 28                                                 [nan]
# 29     [minimum, requirement, minimum, 1, year, custo...
# ...                                                  ...
# 17850        [assessor, award, a1, taqa, etc, transport]
# 17851  [requires, ability, become, forklift, certifie...
# 17852                                              [nan]
# 17853  [responsibility, determines, requirement, work...
# 17854                                              [nan]
# 17855  [track, record, developing, native, android, a...
# 17856  [must, expert, turning, wireframes, mockups, h...
# 17857  [able, lead, technical, side, start, expect, f...
# 17858  [job, requirementsthe, ideal, candidate, seaso...
# 17859  [io, programming, objective, c, c, url_01a736d...
# 17860                     [provide, 24x7, call, support]
# 17861  [skill, looking, bsc, degree, computer, scienc...
# 17862  [four, year, degree, counseling, related, fiel...
# 17863  [know, microsoft, window, sql, server, oracle,...
# 17864                                              [nan]
# 17865  [comfortable, phone, fluent, french, english, ...
# 17866  [additional, duty, ingest, log, label, footage...
# 17867  [proficient, experience, microsoft, word, exce...
# 17868                                              [nan]
# 17869  [responsibility, extensive, knowledge, sample,...
# 17870  [must, minimum, 3, year, financial, planning, ...
# 17871  [ged, diploma, required, requires, minimum, on...
# 17872  [ba, b, computer, science, related, technical,...
# 17873  [required, skill, associate, degree, combinati...
# 17874                                              [nan]
# 17875  [ace, role, eat, comprehensive, statement, wor...
# 17876  [b, b, accounting, desire, fun, love, genuine,...
# 17877  [least, 12, year, professional, experience, ab...
# 17878  [1, must, fluent, latest, version, corel, adob...
# 17879  [want, hear, depth, understanding, oo, program...
#
# [17880 rows x 6 columns]

# %%
## We are Narrowing our scope to Industries for analysing fraud terms
# First we will check frequency distribution plot to check which industry has more job posting 

data_industry = df_new["industry"]
data_industry = data_industry.dropna()

import nltk
fdist = nltk.FreqDist(data_industry)
fdist.values()
fdist.most_common()
# fdist(font.size': 22)
fdist.plot(10)

# %% [markdown]
# ### It can be seen that the Industry- Information Technology and Services has highest numbers of posts so we will narrow down our scope to IT for further analysis.

# %%
### using the already created subset and dropping missing values from it
df_new = df_new.fillna(' ')
df_new.isnull().sum()
df_new = df_new.dropna()
df_new.head()
# Out:
#                     industry  \
# 0
# 1  Marketing and Advertising
# 2
# 3          Computer Software
# 4     Hospital & Health Care
#
#                                          description fraudulent  \
# 0  [food52, fast, growing, james, beard, award, w...          f
# 1  [organised, focused, vibrant, awesome, passion...          f
# 2  [client, located, houston, actively, seeking, ...          f
# 3  [company, esri, environmental, system, researc...          f
# 4  [job, title, itemization, review, managerlocat...          f
#
#                                      company_profile  \
# 0  [food52, created, groundbreaking, award, winni...
# 1  [90, second, world, cloud, video, production, ...
# 2  [valor, service, provides, workforce, solution...
# 3  [passion, improving, quality, life, geography,...
# 4  [spotsource, solution, llc, global, human, cap...
#
#                                             benefits  \
# 0                                              [nan]
# 1  [get, usthrough, part, 90, second, team, gain,...
# 2                                              [nan]
# 3  [culture, anything, corporate, collaborative, ...
# 4                           [full, benefit, offered]
#
#                                         requirements
# 0  [experience, content, management, system, majo...
# 1  [expect, key, responsibility, communicate, cli...
# 2  [implement, pre, commissioning, commissioning,...
# 3  [education, bachelor, master, gi, business, ad...
# 4  [qualification, rn, license, state, texasdiplo...

# %%
# here we have filtered our subset of dataset with Information Technology and Services as industry 
df_IT = df_new[df_new.industry == "Information Technology and Services"]
df_IT.head()
# Out:
#                                industry  \
# 8   Information Technology and Services
# 10  Information Technology and Services
# 52  Information Technology and Services
# 59  Information Technology and Services
# 79  Information Technology and Services
#
#                                           description fraudulent  \
# 8   [implementation, configuration, testing, train...          f
# 10  [position, url_86fd830a95a64e2b30ceed829e63fd3...          f
# 52  [namely, agile, startup, dedicated, building, ...          f
# 59  [apcera, revolutionizing, enterprise, technolo...          f
# 79  [raygun, fast, growing, mindscape, product, ur...          f
#
#                                       company_profile  \
# 8   [solutions3, woman, owned, small, business, wh...
# 10                                              [nan]
# 52  [namely, leading, end, end, hr, payroll, platf...
# 59  [land, roll, sleeve, get, done, create, solve,...
# 79  [mindscape, wellington, based, software, devel...
#
#                                              benefits  \
# 8                                               [nan]
# 10  [benefit, fullbonus, eligible, yesinterview, t...
# 52                                              [nan]
# 59  [competitive, salary, equitygreat, location, h...
# 79  [part, fast, growing, company, team, direct, i...
#
#                                          requirements
# 8   [must, u, citizen, active, sci, clearance, req...
# 10  [position, url_86fd830a95a64e2b30ceed829e63fd3...
# 52  [qualification, payroll, payroll, tax, process...
# 59  [responsibility, work, ux, architect, prototyp...
# 79  [3, year, experience, project, product, manage...

# %%
# Analysing the lemma token of the description column for fraudulent true values with respect to IT Industry

lemma_tokens_description  = df_IT['description']

from collections import Counter

fraudulent_index = df_IT['fraudulent'] == "t"


fraudulent_words = []
nonfraudulent_words = []


for items in lemma_tokens_description[fraudulent_index]:
    fraudulent_words.extend(items)    


for items in lemma_tokens_description[~fraudulent_index]:
    nonfraudulent_words.extend(items)

    
#counter function
counter_fraudwords = Counter(fraudulent_words)
counter_nonfraudwords = Counter(nonfraudulent_words)

# print(counter_fraudwords)
# print(counter_nonfraudwords)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax = plt.subplots(2, 1, figsize=(18,18))
# sns.set(font_scale=2.5)

sns.barplot(x = [items[0] for items in counter_fraudwords.most_common(14)],y = [items[1] for items in counter_fraudwords.most_common(14)], ax=ax[0], palette="rocket")
ax[0].set_title('Top 15 Fraudulent Terms of Job Description',fontsize=20)

sns.barplot(x = [items[0] for items in counter_nonfraudwords.most_common(14)],y = [items[1] for items in counter_nonfraudwords.most_common(14)], ax=ax[1],palette="vlag")
ax[1].set_title("Top 15 Non-Fraudulent Terms of Job Description",fontsize=20);

sns.set(font_scale=2.5)

# %% [markdown]
# ### From the above frequency charts of Fraudulent and Non-Fraudulent lemmas can bee seen. To get the more clear picture we can also analyse the n-grams further.

# %% [markdown]
# # Probability Distribution for Fraud and Legits using language Modeling technique - (N-grams)

# %%
# Subset of the data frame where fraudulent is true
fraud  = df_new[df_new.fraudulent == "t"]

# %%
# Subset of the data frame where fraudulent is true
legit  = df_new[df_new.fraudulent == "f"]

# %%
#Combined text of all the columumns for fraudulant true
text_fraud = fraud[fraud.columns[0:-1]].apply(lambda x: ','.join(x.dropna().astype(str).str.replace('[', '').str.replace(']', '')),axis=1)

# print(len(text_fraud))
# print(text_fraud.head())

# %%
#Combined text of all the column for fraudulant false
text_legit = legit[legit.columns[0:-1]].apply(lambda x: ','.join(x.dropna().astype(str).str.replace('[', '').str.replace(']', '')),axis=1)

# print(len(text_legit))
# print(text_legit.head())

# %%
# LANGUAGE MODELING USING N-GRAMS
# plotting for 4 grams and 3 grams

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def three_grams(corpus, n=None):
    cv = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = cv.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]


fig, axes = plt.subplots(ncols=2, figsize=(25, 40))
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.tight_layout()
sns.set(font_scale=2.5)

top_threegrams_fraud=three_grams(text_fraud)[:25]
x,y=map(list,zip(*top_threegrams_fraud))
sns.barplot(x=y,y=x, ax=axes[0], color='pink')


top_threegrams_legit=three_grams(text_legit)[:25]
x,y=map(list,zip(*top_threegrams_legit))
sns.barplot(x=y,y=x, ax=axes[1], color='teal')


axes[0].set_ylabel(' ')
axes[1].set_ylabel(' ')

# fig.subplots_adjust(wspace=2)


axes[0].set_title('25 most common three_grams for fradulent postings', fontsize=35)
axes[1].set_title('25 most common three_grams for legit postings', fontsize=35)

plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def four_grams(corpus, n=None):
    cv = CountVectorizer(ngram_range=(4, 4)).fit(corpus)
    bag_of_words = cv.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]


fig, axes = plt.subplots(ncols=2, figsize=(25, 40))
plt.subplots_adjust(hspace=0.4, wspace=0.4)
plt.tight_layout()
sns.set(font_scale=2.5)


top_fourgrams=four_grams(text_fraud)[:24]
x,y=map(list,zip(*top_fourgrams))
sns.barplot(x=y,y=x, ax=axes[0], color='pink')


top_fourgrams1=four_grams(text_legit)[:24]
x,y=map(list,zip(*top_fourgrams1))
sns.barplot(x=y,y=x, ax=axes[1], color='teal')
# 

axes[0].set_ylabel(' ')
axes[1].set_ylabel(' ')
# fig.subplots_adjust(wspace=2)


axes[0].set_title('25 most common four_grams for fradulent postings', fontsize=35)
axes[1].set_title('25 most common four_grams for legit postings', fontsize=35)

plt.show()

# %% [markdown]
# # Word Cloud for Fraud Job Posting's Description

# %%
#look at the frequency distribution of single words
# pip install wordcloud
import matplotlib.pyplot as plt
from PIL import Image
import wordcloud
from wordcloud import WordCloud
from collections import Counter 
fraudword_count = Counter()

#we are displaying cloud for description column only here 
fraud['description'].apply(fraudword_count.update)
plt.figure(figsize=(25,30),facecolor='k')
wordcloud_all = WordCloud(max_words=200,background_color="black").generate_from_frequencies(fraudword_count)
plt.title("Wordcloud for Fraudulant Posts", fontsize=10)
plt.axis("off")
plt.imshow(wordcloud_all,interpolation='bilinear')
plt.show()

# %%
#we are displaying cloud for description column only here 
legit['description'].apply(fraudword_count.update)
plt.figure(figsize=(25,30),facecolor='k')
wordcloud_all = WordCloud(max_words=200,background_color="white").generate_from_frequencies(fraudword_count)
plt.title("Wordcloud for Fraudulant Posts", fontsize=10)
plt.axis("off")
plt.imshow(wordcloud_all,interpolation='bilinear')
plt.show()
